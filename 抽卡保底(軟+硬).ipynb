# %% [markdown]
# <a href="https://colab.research.google.com/github/changlinfan/card-Expected-value/blob/main/%E6%8A%BD%E5%8D%A1%E4%BF%9D%E5%BA%95(%E8%BB%9F%2B%E7%A1%AC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  軟保底抽卡期望值模擬

import matplotlib.pyplot as plt

# 抽卡設定參數
n = 100  # 總抽數
p = 0.005  # 初始SSR機率(0.5%)
soft_pity_start = 70  # 軟保底開始
hard_pity = 100  # 硬保底
pity_increment = 0.005  # 每抽機率增加 0.5%

# 每抽中SSR的機率
draw_probs = []
for i in range(1, n + 1):
    if i < soft_pity_start:
        draw_probs.append(p)
    elif i < hard_pity:
        inc = (i - soft_pity_start + 1) * pity_increment
        draw_probs.append(min(p + inc, 1.0))
    else:
        draw_probs.append(1.0)

# 每抽「第一次中SSR」的機率（非累積機率）

first_hit_probs = []
cum_prob = 1.0
for prob in draw_probs:
    first = prob * cum_prob
    first_hit_probs.append(first)
    cum_prob *= (1 - prob)


# 計算期望值
expected_draws = sum([i * prob for i, prob in enumerate(first_hit_probs, start=1)])

print(f"🎯 模型期望抽數：約 {expected_draws:.2f} 抽可中 1 SSR")

# 畫圖視覺化
plt.figure(figsize=(14, 7))
plt.plot(range(1, n + 1), draw_probs, label="每抽中SSR機率")
plt.plot(range(1, n + 1), first_hit_probs, label="每抽首次中SSR機率")
plt.axvline(expected_draws, color='r', linestyle='--', label=f"期望抽數 ≈ {expected_draws:.2f}")
plt.title("軟保底抽卡機率分析")
plt.xlabel("第幾抽")
plt.ylabel("機率")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 🎯 模型期望抽數：約 69.91 抽可中 1 SSR

# %%
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2025-08-17 05:27:48--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 142.250.141.139, 142.250.141.138, 142.250.141.101, ...
# Connecting to drive.google.com (drive.google.com)|142.250.141.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2025-08-17 05:27:49--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# ...
